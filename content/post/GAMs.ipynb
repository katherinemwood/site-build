# %%
import numpy as np
import pandas as pd
from pygam import LinearGAM
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
db = load_diabetes()

# %%
features, target = db.data, db.target

# %%
X = pd.DataFrame(features, columns=db.feature_names)
y = pd.Series(target)

# %%
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %% [markdown]
# The data have been mean-centered and rescaled so that the sum of squares for each column is 0

# %%
X.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11ba29ac0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c165ee0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c19a7c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c1d1df0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c1f7880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c22e100>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c22efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c2638b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c2b5a00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c2ea280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c3208e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c320b80>]],
#       dtype=object)

# %%
#Train-test split
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.25, random_state=13)

# %%
#Linear regression model
linreg = LinearRegression().fit(Xtrain, ytrain)

# %%
#GAM
#all terms are spline except for sex, which is factor (does it matter? can try both)
#first try 10 splines and lambda = .6
gam = LinearGAM().fit(Xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-d10e11653a6c> in <module>
#       2 #all terms are spline except for sex, which is factor (does it matter? can try both)
#       3 #first try 10 splines and lambda = .6
# ----> 4 gam = LinearGAM().fit(Xtrain, ytrain)
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/pygam.py in fit(self, X, y, weights)
#     918
#     919         # optimize
# --> 920         self._pirls(X, y, weights)
#     921         # if self._opt == 0:
#     922         #     self._pirls(X, y, weights)
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/pygam.py in _pirls(self, X, Y, weights)
#     703         # if we dont have any constraints, then do cholesky now
#     704         if not self.terms.hasconstraint:
# --> 705             E = self._cholesky(S + P, sparse=False, verbose=self.verbose)
#     706
#     707         min_n_m = np.min([m,n])
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/pygam.py in _cholesky(self, A, **kwargs)
#     483         while constraint_l2 <= self._constraint_l2_max:
#     484             try:
# --> 485                 L = cholesky(A, **kwargs)
#     486                 self._constraint_l2 = constraint_l2
#     487                 return L
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/utils.py in cholesky(A, sparse, verbose)
#      57             P = sp.sparse.lil_matrix(A.shape)
#      58             p = F.P()
# ---> 59             P[np.arange(len(p)), p] = 1
#      60
#      61             # permute
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/scipy/sparse/lil.py in __setitem__(self, key, x)
#     334             return self._set_intXint(key[0], key[1], x)
#     335         # Everything else takes the normal path.
# --> 336         IndexMixin.__setitem__(self, key, x)
#     337
#     338     def _mul_scalar(self, other):
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/scipy/sparse/_index.py in __setitem__(self, key, x)
#      97             col = np.atleast_1d(col)
#      98
# ---> 99         i, j = _broadcast_arrays(row, col)
#     100         if i.shape != j.shape:
#     101             raise IndexError('number of row and column indices differ')
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/scipy/sparse/_index.py in _broadcast_arrays(a, b)
#      24     x, y = np.broadcast_arrays(a, b)
#      25     x.flags.writeable = a.flags.writeable
# ---> 26     y.flags.writeable = b.flags.writeable
#      27     return x, y
#      28
#
# ValueError: cannot set WRITEABLE flag to True of this array

# %%
Xtrain
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 165 -0.041840 -0.044642 -0.066563 -0.046985 -0.037344 -0.043276  0.048640
# 100  0.016281 -0.044642  0.017506 -0.022885  0.060349  0.044406  0.030232
# 177  0.048974 -0.044642  0.027206 -0.025180  0.023198  0.018414 -0.061809
# 284  0.041708  0.050680 -0.022373  0.028758 -0.066239 -0.045155 -0.061809
# 287  0.045341 -0.044642 -0.006206 -0.015999  0.125019  0.125198  0.019187
# ..        ...       ...       ...       ...       ...       ...       ...
# 230 -0.038207  0.050680  0.071397 -0.057314  0.153914  0.155887  0.000779
# 16  -0.005515 -0.044642  0.042296  0.049415  0.024574 -0.023861  0.074412
# 74   0.012648  0.050680  0.002417  0.056301  0.027326  0.017162  0.041277
# 176  0.045341  0.050680  0.019662  0.039087  0.020446  0.025930  0.008142
# 338 -0.063635 -0.044642 -0.033151 -0.033214  0.001183  0.024051 -0.024993
#
#            s4        s5        s6
# 165 -0.039493 -0.056158 -0.013504
# 100 -0.002592  0.037232 -0.001078
# 177  0.080066  0.072224  0.032059
# 284 -0.002592  0.002864 -0.054925
# 287  0.034309  0.032433 -0.005220
# ..        ...       ...       ...
# 230  0.071948  0.050276  0.069338
# 16  -0.039493  0.052280  0.027917
# 74  -0.039493  0.003712  0.073480
# 176 -0.002592 -0.003304  0.019633
# 338 -0.002592 -0.022512 -0.059067
#
# [331 rows x 10 columns]

# %%
from sklearn.datasets import load_boston
boston = load_boston()
df = pd.DataFrame(boston.data, columns=boston.feature_names)
target_df = pd.Series(boston.target)

X = df
y = target_df
gam = LinearGAM().fit(X, y)
gam.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-2463e40cf7a9> in <module>
#       6 X = df
#       7 y = target_df
# ----> 8 gam = LinearGAM().fit(X, y)
#       9 gam.summary()
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/pygam.py in fit(self, X, y, weights)
#     918
#     919         # optimize
# --> 920         self._pirls(X, y, weights)
#     921         # if self._opt == 0:
#     922         #     self._pirls(X, y, weights)
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/pygam.py in _pirls(self, X, Y, weights)
#     703         # if we dont have any constraints, then do cholesky now
#     704         if not self.terms.hasconstraint:
# --> 705             E = self._cholesky(S + P, sparse=False, verbose=self.verbose)
#     706
#     707         min_n_m = np.min([m,n])
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/pygam.py in _cholesky(self, A, **kwargs)
#     483         while constraint_l2 <= self._constraint_l2_max:
#     484             try:
# --> 485                 L = cholesky(A, **kwargs)
#     486                 self._constraint_l2 = constraint_l2
#     487                 return L
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/pygam/utils.py in cholesky(A, sparse, verbose)
#      57             P = sp.sparse.lil_matrix(A.shape)
#      58             p = F.P()
# ---> 59             P[np.arange(len(p)), p] = 1
#      60
#      61             # permute
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/scipy/sparse/lil.py in __setitem__(self, key, x)
#     334             return self._set_intXint(key[0], key[1], x)
#     335         # Everything else takes the normal path.
# --> 336         IndexMixin.__setitem__(self, key, x)
#     337
#     338     def _mul_scalar(self, other):
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/scipy/sparse/_index.py in __setitem__(self, key, x)
#      97             col = np.atleast_1d(col)
#      98
# ---> 99         i, j = _broadcast_arrays(row, col)
#     100         if i.shape != j.shape:
#     101             raise IndexError('number of row and column indices differ')
#
# ~/anaconda3/envs/pd1/lib/python3.8/site-packages/scipy/sparse/_index.py in _broadcast_arrays(a, b)
#      24     x, y = np.broadcast_arrays(a, b)
#      25     x.flags.writeable = a.flags.writeable
# ---> 26     y.flags.writeable = b.flags.writeable
#      27     return x, y
#      28
#
# ValueError: cannot set WRITEABLE flag to True of this array
